# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
link = "../Data/processed/region3_daily.csv"
# data frame
dfRegion3Daily = pd.read_csv(link, index_col='Date', parse_dates=True, dayfirst=True)
dfRegion3Daily.head(3)
# Out:
#             denguecases  AveUVIndex  MinUVIndex  MaxUVIndex        PSI  \
# Date
# 2016-01-01        405.0         NaN         NaN         NaN  39.333333
# 2016-02-01        404.0         NaN         NaN         NaN  50.375000
# 2016-03-01        404.0         NaN         NaN         NaN  47.125000
#
#             Rainfall_mm  Highest_30Min_Rainfall_mm  Highest_60Min_Rainfall_mm  \
# Date
# 2016-01-01     6.528571                   3.814286                   4.100000
# 2016-02-01    19.966667                   8.166667                  11.500000
# 2016-03-01     1.066667                   0.400000                   0.633333
#
#             Highest_120Min_Rainfall_mm  Mean_Temperature_C  Max_Temperature_C  \
# Date
# 2016-01-01                    5.385714               26.40               28.7
# 2016-02-01                   15.566667               25.30               27.4
# 2016-03-01                    0.733333               25.65               26.9
#
#             Min_Temperature_C  Mean_WindSpeed_kmh  Max_WindSpeed_kmh  \
# Date
# 2016-01-01          24.866667            9.366667          37.666667
# 2016-02-01          22.900000            5.950000          40.300000
# 2016-03-01          24.750000            5.400000          30.250000
#
#             Max_Humidity_Percentage   Mean_Humidity_Percentage  \
# Date
# 2016-01-01                      100                         84
# 2016-02-01                      100                         90
# 2016-03-01                      100                         92
#
#              Min_Humidity_Percentage  regionId
# Date
# 2016-01-01                        64         3
# 2016-02-01                        82         3
# 2016-03-01                        83         3

# %%
dfRegion3Daily.plot(subplots=True, figsize=(18.5, 10.5));

# %%
dfRegion3Daily.plot(figsize=(18.5, 10.5));

# %%
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
#plot
dfRegion3Daily['denguecases'].plot(label="Cluster cases", legend=True, kind='bar')

# %%
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
#plot
dfRegion3Daily['denguecases'].plot(label="Cluster cases", legend=True)
dfRegion3Daily['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion3Daily['PSI'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion3Daily['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion3Daily['Mean_Temperature_C'].plot(secondary_y=True, label="Temperature", legend=True)

# %%
link = "../Data/processed/region3_week.csv"
# data frame
dfRegion3Weekly = pd.read_csv(link, index_col='WW')
dfRegion3Weekly.head(3)
# Out:
#     denguecases  AveUVIndex  MinUVIndex  MaxUVIndex        PSI  Rainfall_mm  \
# WW
# 1         404.0         NaN         NaN         NaN  44.854167    12.730769
# 2         416.0         NaN         NaN         NaN  39.839286     2.231579
# 3         514.0         NaN         NaN         NaN  41.291667     7.257143
#
#     Highest_30Min_Rainfall_mm  Highest_60Min_Rainfall_mm  \
# WW
# 1                    5.823077                   7.515385
# 2                    1.631579                   1.963158
# 3                    4.761905                   5.695238
#
#     Highest_120Min_Rainfall_mm  Mean_Temperature_C  Max_Temperature_C  \
# WW
# 1                    10.084615           25.850000          28.180000
# 2                     2.057895           27.707143          31.335714
# 3                     6.476190           28.007143          32.107143
#
#     Min_Temperature_C  Mean_WindSpeed_kmh  Max_WindSpeed_kmh  \
# WW
# 1           24.080000            8.000000          38.720000
# 2           25.550000            6.892857          33.014286
# 3           25.785714            5.692857          28.128571
#
#     Max_Humidity_Percentage   Mean_Humidity_Percentage  \
# WW
# 1                100.000000                  87.000000
# 2                 93.571429                  81.000000
# 3                 90.428571                  79.142857
#
#      Min_Humidity_Percentage  regionId
# WW
# 1                  73.000000         3
# 2                  60.142857         3
# 3                  58.000000         3

# %%
dfRegion3Weekly.plot(figsize=(18.5, 10.5));

# %%
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
# plot
dfRegion3Weekly['denguecases'].plot(label="Cluster cases", legend=True, kind='bar')
dfRegion3Weekly['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion3Weekly['PSI'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion3Weekly['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion3Weekly['Mean_Temperature_C'].plot(secondary_y=True, label="Temperature", legend=True)

# %%
dfRegion3Weekly[['denguecases','Rainfall_mm','PSI','MaxUVIndex','Mean_Temperature_C']].plot(subplots=True, figsize=(18.5, 10.5));

# %%
dfRegion3Weekly.plot(subplots=True, figsize=(18.5, 10.5));

# %%
link = "../Data/processed/region3_month.csv"
# data frame
dfRegion3Monthly = pd.read_csv(link, index_col='month')
dfRegion3Monthly.head(3)
# Out:
#        denguecases  AveUVIndex  MinUVIndex  MaxUVIndex        PSI  \
# month
# 1              672         NaN         NaN         NaN  45.129032
# 2              226         NaN         NaN         NaN  49.377874
# 3              225         3.0         0.0         8.0  54.787634
#
#        Rainfall_mm  Highest_30Min_Rainfall_mm  Highest_60Min_Rainfall_mm  \
# month
# 1         6.514208                   4.274863                   5.002732
# 2         6.378161                   2.741379                   3.398851
# 3         3.070968                   1.807527                   2.361290
#
#        Highest_120Min_Rainfall_mm  Mean_Temperature_C  Max_Temperature_C  \
# month
# 1                        5.576503           27.619355          31.455556
# 2                        4.052874           27.263793          30.756897
# 3                        2.808602           28.348387          32.575806
#
#        Min_Temperature_C  Mean_WindSpeed_kmh  Max_WindSpeed_kmh  \
# month
# 1              25.411111            6.360317          32.522222
# 2              24.979310            7.431034          36.760345
# 3              25.985484            7.127419          32.537097
#
#        Max_Humidity_Percentage  Mean_Humidity_Percentage  \
# month
# 1                    91.967742                 79.774194
# 2                    91.310345                 79.034483
# 3                    88.354839                 74.935484
#
#        Min_Humidity_Percentage  regionId
# month
# 1                    59.645161         3
# 2                    60.206897         3
# 3                    51.806452         3

# %%
dfRegion3Monthly.plot(subplots=True, figsize=(18.5, 10.5));

# %%
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
# plot
plt.title('Monthly 2016')
dfRegion3Monthly['denguecases'].plot(label="Cluster cases", legend=True, kind='bar')
dfRegion3Monthly['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion3Monthly['PSI'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion3Monthly['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion3Monthly['Mean_Temperature_C'].plot(secondary_y=True, label="Mean Temp", legend=True)
dfRegion3Monthly['Max_Temperature_C'].plot(secondary_y=True, label="Max Temp", legend=True)
dfRegion3Monthly['Mean_Humidity_Percentage'].plot(secondary_y=True, label="Mean Humidity", legend=True)
dfRegion3Monthly['Max_Humidity_Percentage'].plot(secondary_y=True, label="Max Humidity", legend=True)

# %%
dfRegion3Monthly[['denguecases','Rainfall_mm','PSI','MaxUVIndex','Mean_Temperature_C','Max_Temperature_C','Mean_Humidity_Percentage','Max_Humidity_Percentage']].plot(subplots=True, figsize=(18.5, 10.5));
