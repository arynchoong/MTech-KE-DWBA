# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
link = "../Data/processed/region1_daily.csv"
# data frame
dfRegion1Daily = pd.read_csv(link, index_col='Date', parse_dates=True, dayfirst=True)
dfRegion1Daily.head(3)
# Out:
#             denguecases  AveUVIndex  MinUVIndex  MaxUVIndex        PSI  \
# Date
# 2016-01-01        114.0         NaN         NaN         NaN  33.958333
# 2016-02-01        114.0         NaN         NaN         NaN  43.958333
# 2016-03-01        114.0         NaN         NaN         NaN  42.833333
#
#             Rainfall_mm  Highest_30Min_Rainfall_mm  Highest_60Min_Rainfall_mm  \
# Date
# 2016-01-01     3.950000                   1.950000                   2.316667
# 2016-02-01    21.833333                   9.516667                  13.083333
# 2016-03-01     2.916667                   1.133333                   1.500000
#
#             Highest_120Min_Rainfall_mm  Mean_Temperature_C  Max_Temperature_C  \
# Date
# 2016-01-01                    2.650000                26.9              29.10
# 2016-02-01                   16.066667                26.3              27.95
# 2016-03-01                    1.733333                26.9              27.55
#
# ...

# %%
dfRegion1Daily.plot(subplots=True, figsize=(18.5, 10.5));

# %%
dfRegion1Daily.plot(figsize=(18.5, 10.5));

# %%
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
#plot
dfRegion1Daily['denguecases'].plot(label="Cluster cases", legend=True)
dfRegion1Daily['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion1Daily['PSI'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion1Daily['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion1Daily['Mean_Temperature_C'].plot(secondary_y=True, label="Temperature", legend=True)

# %%
link = "../Data/processed/region2_daily.csv"
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
# data frame
dfRegion2Daily = pd.read_csv(link, index_col='Date', parse_dates=True, dayfirst=True)
dfRegion2Daily['denguecases'].plot(label="Cluster cases", legend=True)
dfRegion2Daily['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion2Daily['PSI'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion2Daily['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion2Daily['Mean_Temperature_C'].plot(secondary_y=True, label="Temperature", legend=True)

# %%
link = "../Data/processed/region3_daily.csv"
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
# data frame
dfRegion3Daily = pd.read_csv(link, index_col='Date', parse_dates=True, dayfirst=True)
dfRegion3Daily['denguecases'].plot(label="Cluster cases", legend=True)
dfRegion3Daily['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion3Daily['PSI'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion3Daily['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion3Daily['Mean_Temperature_C'].plot(secondary_y=True, label="Temperature", legend=True)

# %%
link = "../Data/processed/region4_daily.csv"
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
# data frame
dfRegion4Daily = pd.read_csv(link, index_col='Date', parse_dates=True, dayfirst=True)
dfRegion4Daily['denguecases'].plot(label="Cluster cases", legend=True)
dfRegion4Daily['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion4Daily['PSI'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion4Daily['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion4Daily['Mean_Temperature_C'].plot(secondary_y=True, label="Temperature", legend=True)

# %%
link = "../Data/processed/region5_daily.csv"
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
# data frame
dfRegion5Daily = pd.read_csv(link, index_col='Date', parse_dates=True, dayfirst=True)
dfRegion5Daily['denguecases'].plot(label="Cluster cases", legend=True)
dfRegion5Daily['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion5Daily['PSI'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion5Daily['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion5Daily['Mean_Temperature_C'].plot(secondary_y=True, label="Temperature", legend=True)

# %%
link = "../Data/processed/region1_week.csv"
# data frame
dfRegion1Weekly = pd.read_csv(link, index_col='WW')
dfRegion1Weekly.head(3)
# Out:
#     Region1  AveUVIndex  MinUVIndex  MaxUVIndex  PSI_region1  Rainfall_mm  \
# WW
# 1     114.0         NaN         NaN         NaN    38.958333    12.891667
# 2      95.0         NaN         NaN         NaN    37.017857     1.316667
# 3     140.0         NaN         NaN         NaN    41.779762     4.676190
#
#     Highest_30Min_Rainfall_mm  Highest_60Min_Rainfall_mm  \
# WW
# 1                    5.733333                   7.700000
# 2                    0.935897                   1.115385
# 3                    3.376190                   4.140476
#
#     Highest_120Min_Rainfall_mm  Mean_Temperature_C  Max_Temperature_C  \
# WW
# 1                     9.358333           26.600000          28.525000
# 2                     1.223077           27.871429          30.928571
# 3                     4.507143           28.314286          31.935714
#
#     Min_Temperature_C  Mean_WindSpeed_kmh  Max_WindSpeed_kmh  \
# WW
# 1           24.375000           14.850000          48.150000
# ...

# %%
dfRegion1Weekly.plot(figsize=(18.5, 10.5));

# %%
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
# plot
dfRegion1Weekly['Region1'].plot(label="Cluster cases", legend=True)
dfRegion1Weekly['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion1Weekly['PSI_region1'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion1Weekly['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion1Weekly['Mean_Temperature_C'].plot(secondary_y=True, label="Temperature", legend=True)

# %%
link = "../Data/processed/region2_week.csv"
# data frame
dfRegion2Weekly = pd.read_csv(link, index_col='WW')
dfRegion2Weekly.head(3)
# Out:
#     denguecases  AveUVIndex  MinUVIndex  MaxUVIndex       PSI  Rainfall_mm  \
# WW
# 1         132.0         NaN         NaN         NaN  35.62500    11.277778
# 2         159.0         NaN         NaN         NaN  37.37500     1.074074
# 3         181.0         NaN         NaN         NaN  43.64881     3.500000
#
#     Highest_30Min_Rainfall_mm  Highest_60Min_Rainfall_mm  \
# WW
# 1                    5.766667                   7.544444
# 2                    0.385185                   0.511111
# 3                    2.457143                   3.264286
#
#     Highest_120Min_Rainfall_mm  Mean_Temperature_C  Max_Temperature_C  \
# WW
# 1                     8.944444           26.950000          28.980000
# 2                     0.600000           28.400000          31.464286
# 3                     3.400000           28.871429          32.471429
#
#     Min_Temperature_C  Mean_WindSpeed_kmh  Max_WindSpeed_kmh  \
# WW
# 1           24.700000           10.440000          43.840000
# ...

# %%
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
# plot
dfRegion2Weekly['denguecases'].plot(label="Cluster cases", legend=True)
dfRegion2Weekly['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion2Weekly['PSI'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion2Weekly['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion2Weekly['Mean_Temperature_C'].plot(secondary_y=True, label="Temperature", legend=True)

# %%
dfRegion2Weekly[['denguecases','Rainfall_mm','Mean_Temperature_C']].plot(subplots=True, figsize=(18.5, 10.5));

# %%
link = "../Data/processed/region3_week.csv"
# data frame
dfRegion3Weekly = pd.read_csv(link, index_col='WW')
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
# plot
dfRegion3Weekly['denguecases'].plot(label="Cluster cases", legend=True)
dfRegion3Weekly['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion3Weekly['PSI'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion3Weekly['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion3Weekly['Mean_Temperature_C'].plot(secondary_y=True, label="Temperature", legend=True)

# %%
dfRegion3Weekly[['denguecases','Rainfall_mm','PSI','MaxUVIndex','Mean_Temperature_C']].plot(subplots=True, figsize=(18.5, 10.5));

# %%
link = "../Data/processed/region4_week.csv"
# data frame
dfRegion4Weekly = pd.read_csv(link, index_col='WW')
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
# plot
dfRegion4Weekly['denguecases'].plot(label="Cluster cases", legend=True)
dfRegion4Weekly['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion4Weekly['PSI'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion4Weekly['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion4Weekly['Mean_Temperature_C'].plot(secondary_y=True, label="Temperature", legend=True)

# %%
dfRegion4Weekly[['denguecases','Rainfall_mm','PSI','MaxUVIndex','Mean_Temperature_C']].plot(subplots=True, figsize=(18.5, 10.5));

# %%
link = "../Data/processed/region5_week.csv"
# data frame
dfRegion5Weekly = pd.read_csv(link, index_col='WW')
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
# plot
plt.title('Weekly 2016')
dfRegion5Weekly['denguecases'].plot(label="Cluster cases", legend=True)
dfRegion5Weekly['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion5Weekly['PSI'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion5Weekly['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion5Weekly['Mean_Temperature_C'].plot(secondary_y=True, label="Temperature", legend=True)

# %%
dfRegion5Weekly[['denguecases','Rainfall_mm','PSI','MaxUVIndex','Mean_Temperature_C']].plot(subplots=True, figsize=(18.5, 10.5));

# %%
dfRegion5Weekly.plot(subplots=True, figsize=(18.5, 10.5));

# %%
link = "../Data/processed/region1_month.csv"
# data frame
dfRegion1Monthly = pd.read_csv(link, index_col='month')
dfRegion1Monthly.head(3)
# Out:
#        denguecases  AveUVIndex  MinUVIndex  MaxUVIndex        PSI  \
# month
# 1              223         NaN         NaN         NaN  41.051075
# 2              287         NaN         NaN         NaN  43.823276
# 3               66         3.0         0.0         8.0  53.706989
#
#        Rainfall_mm  Highest_30Min_Rainfall_mm  Highest_60Min_Rainfall_mm  \
# month
# 1         4.980645                   3.340437                   3.981967
# 2         6.288439                   2.465896                   3.147977
# 3         2.464674                   1.542391                   1.875000
#
#        Highest_120Min_Rainfall_mm  Mean_Temperature_C  Max_Temperature_C  \
# month
# 1                        4.308197           28.009677          31.346774
# 2                        3.797688           27.817241          30.834483
# 3                        2.192391           28.835484          32.338710
#
#        Min_Temperature_C  Mean_WindSpeed_kmh  Max_WindSpeed_kmh  \
# month
# ...

# %%
dfRegion1Monthly.plot(subplots=True, figsize=(18.5, 10.5));

# %%
#set plot size
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5);
# plot
plt.title('Monthly 2016')
dfRegion1Monthly['denguecases'].plot(label="Cluster cases", legend=True)
dfRegion1Monthly['Rainfall_mm'].plot(secondary_y=True, label="Rainfall", legend=True)
dfRegion1Monthly['PSI'].plot(secondary_y=True, label="PSI", legend=True)
dfRegion1Monthly['MaxUVIndex'].plot(secondary_y=True, label="UVI", legend=True)
dfRegion1Monthly['Mean_Temperature_C'].plot(secondary_y=True, label="Mean Temp", legend=True)
dfRegion1Monthly['Max_Temperature_C'].plot(secondary_y=True, label="Max Temp", legend=True)
dfRegion1Monthly['Mean_Humidity_Percentage'].plot(secondary_y=True, label="Mean Humidity", legend=True)
dfRegion1Monthly['Max_Humidity_Percentage'].plot(secondary_y=True, label="Max Humidity", legend=True)

# %%
dfRegion1Monthly[['denguecases','Rainfall_mm','PSI','MaxUVIndex','Mean_Temperature_C','Max_Temperature_C','Mean_Humidity_Percentage','Max_Humidity_Percentage']].plot(subplots=True, figsize=(18.5, 10.5));

# %%
link = "../Data/processed/region2_month.csv"
# data frame
dfRegion2Monthly = pd.read_csv(link, index_col='month')
dfRegion2Monthly[['denguecases','Rainfall_mm','PSI','MaxUVIndex','Mean_Temperature_C','Max_Temperature_C','Mean_Humidity_Percentage','Max_Humidity_Percentage']].plot(subplots=True, figsize=(18.5, 10.5));

# %%
link = "../Data/processed/region3_month.csv"
# data frame
dfRegion3Monthly = pd.read_csv(link, index_col='month')
dfRegion3Monthly[['denguecases','Rainfall_mm','PSI','MaxUVIndex','Mean_Temperature_C','Max_Temperature_C','Mean_Humidity_Percentage','Max_Humidity_Percentage']].plot(subplots=True, figsize=(18.5, 10.5));

# %%
link = "../Data/processed/region4_month.csv"
# data frame
dfRegion4Monthly = pd.read_csv(link, index_col='month')
dfRegion4Monthly[['denguecases','Rainfall_mm','PSI','MaxUVIndex','Mean_Temperature_C','Max_Temperature_C','Mean_Humidity_Percentage','Max_Humidity_Percentage']].plot(subplots=True, figsize=(18.5, 10.5));

# %%
link = "../Data/processed/region5_month.csv"
# data frame
dfRegion5Monthly = pd.read_csv(link, index_col='month')
dfRegion5Monthly[['denguecases','Rainfall_mm','PSI','MaxUVIndex','Mean_Temperature_C','Max_Temperature_C','Mean_Humidity_Percentage','Max_Humidity_Percentage']].plot(subplots=True, figsize=(18.5, 10.5));
